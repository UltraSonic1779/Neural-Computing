# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

n = 10  # how many records we will display
plt.figure(figsize=(12, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, UpSampling2D, Reshape

# %%
encode_model = Sequential()

############
# Encoding #
############

## FIRST SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=16, kernel_size=(3,3), input_shape=(28, 28, 1), activation='relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2),  padding='same'))

## SECOND SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation = 'relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2), padding='same'))

## THIRD SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
encode_model.add(Flatten(input_shape=[7,7,8]))
encode_model.add(Dense(7*7*8, activation="relu"))
encode_model.add(Dense(30, activation="relu"))
# Out:
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
############
# Decoding #
############
decode_model=Sequential()

# DeConv1
#decode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same'))
# Upsampling LAYER
#decode_model.add(UpSampling2D((2, 2)))

decode_model.add(Dense(7*7*8,activation="relu"))
decode_model.add(Reshape([7,7,8]))

# DeConv2
decode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same'))
# Upsampling LAYER
decode_model.add(UpSampling2D((2, 2)))

# Deconv3
decode_model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same'))
# POOLING LAYER
decode_model.add(UpSampling2D((2, 2)))

decode_model.add(Conv2D(1, kernel_size=(3,3), activation='sigmoid', padding='same'))

# %%
autoencoder = Sequential([encode_model, decode_model])

# %%
encode_model.compile(optimizer='adam', loss='binary')
# Out:
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
autoencoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 30)                42310
#
#  sequential_1 (Sequential)   (None, 28, 28, 1)         14049
#
# =================================================================
# Total params: 56359 (220.15 KB)
# Trainable params: 56359 (220.15 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
encode_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 8)           0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           584
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 8)           0
#  g2D)
#
#  flatten (Flatten)           (None, 72)                0
#
#  dense (Dense)               (None, 392)               28616
#
#  dense_1 (Dense)             (None, 30)                11790
#
# =================================================================
# Total params: 42310 (165.27 KB)
# Trainable params: 42310 (165.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
decode_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 392)               12152
#
#  reshape (Reshape)           (None, 7, 7, 8)           0
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 8)           584
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 8)         0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 16)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 14049 (54.88 KB)
# Trainable params: 14049 (54.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_train = x_train.reshape(60000,28,28,1)
x_train = x_train/255
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_test = x_test.reshape(10000, 28, 28, 1)
x_test = x_test/255
x_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
autoencoder.compile(optimizer = 'adam',
                    loss = 'binary_crossentropy',
                    metrics = ['accuracy'])

# %%
# Train the model
autoencoder.fit(x=x_train, y=x_train,  epochs=10, batch_size=128, shuffle=True, verbose=1, validation_data=(x_test, x_test))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 469/469 [==============================] - 13s 24ms/step - loss: 0.2282 - accuracy: 0.7985 - val_loss: 0.1527 - val_accuracy: 0.8014
# Epoch 2/10
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1413 - accuracy: 0.8049 - val_loss: 0.1316 - val_accuracy: 0.8045
# Epoch 3/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1284 - accuracy: 0.8073 - val_loss: 0.1238 - val_accuracy: 0.8085
# Epoch 4/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1225 - accuracy: 0.8084 - val_loss: 0.1191 - val_accuracy: 0.8079
# Epoch 5/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1188 - accuracy: 0.8091 - val_loss: 0.1155 - val_accuracy: 0.8085
# Epoch 6/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1158 - accuracy: 0.8096 - val_loss: 0.1126 - val_accuracy: 0.8089
# Epoch 7/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1135 - accuracy: 0.8100 - val_loss: 0.1116 - val_accuracy: 0.8100
# Epoch 8/10
# 469/469 [==============================] - 10s 20ms/step - loss: 0.1115 - accuracy: 0.8103 - val_loss: 0.1093 - val_accuracy: 0.8093
# Epoch 9/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1098 - accuracy: 0.8106 - val_loss: 0.1078 - val_accuracy: 0.8095
# Epoch 10/10
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1083 - accuracy: 0.8108 - val_loss: 0.1073 - val_accuracy: 0.8097

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
autoencoder.fit(x_train, x_train,  epochs=5, batch_size=32, shuffle=True, verbose=1, validation_data=(x_test, x_test))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1082 - accuracy: 0.8109 - val_loss: 0.1056 - val_accuracy: 0.8104
# Epoch 2/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1052 - accuracy: 0.8114 - val_loss: 0.1027 - val_accuracy: 0.8108
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1033 - accuracy: 0.8117 - val_loss: 0.1009 - val_accuracy: 0.8113
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1019 - accuracy: 0.8120 - val_loss: 0.1001 - val_accuracy: 0.8112
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1007 - accuracy: 0.8122 - val_loss: 0.0988 - val_accuracy: 0.8117

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

plt.figure(figsize=(12, 4), facecolor='green')
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
autoencoder.fit(x_train, x_train,  epochs=1, batch_size=64, shuffle=True, verbose=1, validation_data=(x_test, x_test))
# Out:
# 938/938 [==============================] - 11s 12ms/step - loss: 0.0985 - accuracy: 0.8125 - val_loss: 0.0974 - val_accuracy: 0.8116

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

plt.figure(figsize=(12, 4), facecolor='gray')
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

plt.figure(figsize=(15, 4), facecolor='green')
for i in range(7):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(True)
    ax.get_yaxis().set_visible(True)
# Out:
# 313/313 [==============================] - 1s 3ms/step
