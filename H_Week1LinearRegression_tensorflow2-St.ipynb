# %% [markdown]
# # Week-1
#
# # Linear Regression Example using tensorflow
# Linear regression implementation with TensorFlow v2 library.
#
# This example is using a low-level approach to better understand all mechanics behind the training process.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
rng = np.random
# Out:
# WARNING:tensorflow:From D:\Softwares\Coding\Anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
learning_rate = 0.01
training_steps = 1000
display_step = 50

# %%
learning_rate = 0.01
training_steps = 100
display_step = 40

# %%
# Just run the next cell using 'Ctrl' + 'Enter'

# %%
# Training Data.

X = np.array([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
              7.042,10.791,5.313,7.997,5.654,9.27,3.1])

Y = np.array([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
              2.827,3.465,1.65,2.904,2.42,2.94,1.3])

n_samples = X.shape[0]

# %%
# Training Data.

X = np.array([3.7, 7.3, 9.5, 6.71, 6.93, 7.179, 4.832, 2.132, 4.21, 7.123,
              2.095, 10.111, 4.321, 5.198, 1.394, 3.60, 7.2])

Y = np.array([4.7, 4.96, 2.09, 5.29, 6.496, 4.573, 5.366, 2.596, 7.53, 6.221,
              2.834, 3.456, 1.61, 3.907, 2.32, 2.92, 1.4])

n_samples = X.shape[0]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(X, '\n', X.shape)
# Out:
# [ 3.7    7.3    9.5    6.71   6.93   7.179  4.832  2.132  4.21   7.123
#   2.095 10.111  4.321  5.198  1.394  3.6    7.2  ]
#  (17,)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(Y, '\n', Y.shape)
# Out:
# [4.7   4.96  2.09  5.29  6.496 4.573 5.366 2.596 7.53  6.221 2.834 3.456
#  1.61  3.907 2.32  2.92  1.4  ]
#  (17,)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
W = tf.Variable(rng.randn(), name = "weight")
b = tf.Variable(rng.randn(), name = "bias")

print(W.numpy(), '\n', b.numpy)
# Out:
# -0.01902138
#  <bound method BaseResourceVariable.numpy of <tf.Variable 'bias:0' shape=() dtype=float32, numpy=0.47382018>>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def linear_regression(x):
    return W * x + b

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def mean_square(y_pred, y_true):
    return tf.reduce_sum(tf.pow(y_pred - y_true, 2)) / (2 * n_samples)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
optimizer = tf.optimizers.SGD(learning_rate)

# %%
# Adding a question mark () after the function name lets you view the latest documentation. 
# This is a handy tool.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tf.optimizers.SGD?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def run_optimization():
    with tf.GradientTape() as g:
        pred = linear_regression(X)
        loss = mean_square(pred, Y)
        
    gradients = g.gradient(loss, [W, b])
    
    optimizer.apply_gradients(zip(gradients, [W, b]))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for step in range(1, training_steps + 1):
    run_optimization()
    
    if step % display_step == 0:
        pred = linear_regression(X)
        loss = mean_square(pred, Y)
        print("step: %i, loss: %f, W: %f, b: %f" % (step, loss, W.numpy(), b.numpy()))
# Out:
# step: 40, loss: 2.123793, W: 0.515304, b: 0.741139
# step: 80, loss: 2.049621, W: 0.489377, b: 0.911463

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot(X, Y, 'ro', label = "Original Data")
plt.plot(X, np.array(W * X + b), label = "Fitted Line")
plt.legend()
plt.show()

# %%
plt.plot(X, Y, '+', label = "Original Data", color = "blue")
plt.plot(X, np.array(W * X + b), label = "Fitted Line", color = "yellow", linestyle = "--")
plt.legend()
plt.show()

# %% [markdown]
# # Lab Logbook requirements:
# ### Please make sure to document the following in your Lablogbook:
#
# Include an image of the generated graph depicting the original data and the fitted line for linear regression. Modify the appearance of the graph by adjusting its color or size. Copy the figure and paste it directly into your logbook. Refrain from taking a snapshot; instead, right-click and copy the graph to your lab logbook. Ensure that no code or other information is added to the logbook and that only required graph is present.
#
# #### Marks will not be awarded if anything else is found in the logbook or instructions are not clearly followed.
